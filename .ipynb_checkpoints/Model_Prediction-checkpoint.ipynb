# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('processed_data_kansas.csv')

df
# Out:
#         Report_No           Reported_Date Reported_Time  \
# 0       160007695  02/01/2016 12:00:00 AM          1:58
# 1       160006559  01/27/2016 12:00:00 AM         13:04
# 2       160023260  04/04/2016 12:00:00 AM          6:35
# 3       160015795  03/05/2016 12:00:00 AM         12:58
# 4       160039800  06/05/2016 12:00:00 AM          0:01
# ...           ...                     ...           ...
# 110492  160014371  02/29/2016 12:00:00 AM          2:51
# 110493  160046842  06/30/2016 12:00:00 AM         14:22
# 110494  160033682  05/13/2016 12:00:00 AM          7:03
# 110495  160006331  01/26/2016 12:00:00 AM         17:45
# 110496  160050919  07/14/2016 12:00:00 AM         23:27
#
#                      From_Date From_Time  Offense IBRS           Description  \
# 0       02/01/2016 12:00:00 AM      1:58     2100  90D  Driving Under Influe
# 1       01/25/2016 12:00:00 AM     17:55      630  23C  Stealing Shoplifting
# 2       04/04/2016 12:00:00 AM      6:35      802  13B  Non Agg Assault Dome
# 3       03/05/2016 12:00:00 AM     12:50     2655  90J           Trespassing
# 4       06/05/2016 12:00:00 AM      0:01      840  90Z  Resisting an Officer
# ...                        ...       ...      ...  ...                   ...
# 110492  02/28/2016 12:00:00 AM     18:34      799  NaN  Auto Theft Outside S
# 110493  06/29/2016 12:00:00 AM     23:00      302  120         Armed Robbery
# 110494  05/13/2016 12:00:00 AM      6:50     1401  290       Property Damage
# 110495  01/23/2016 12:00:00 AM      8:00      650  23G  Stealing Auto Parts/
# 110496  05/20/2016 12:00:00 AM      3:09      799  NaN  Auto Theft Outside S
#
#          Beat                  Address  ... Zip Code  Rep_Dist Area DVFlag  \
# 0       142.0      E 39 ST/GARFIELD AV  ...  64109.0    PJ3116  CPD      U
# 1       421.0           7100  NW 86 TE  ...  64153.0    PP0317  NPD      N
# 2       141.0        E 39 ST/TROOST AV  ...  64110.0    PJ3070  CPD      Y
# 3       112.0              00  W 10 ST  ...  64105.0    PJ0865  CPD      U
# 4       223.0         E 63 ST/SWOPE PK  ...  64120.0    PJ4922  MPD      U
# ...       ...                      ...  ...      ...       ...  ...    ...
# 110492  226.0  EAST 63 TRFY & LEWIS RD  ...  64110.0       NaN  NaN      U
# 110493    NaN           41ST & GILLHAM  ...      NaN       NaN  NaN      U
# 110494    NaN             40 & 435 HWY  ...  64132.0       NaN  NaN      U
# 110495    NaN          1 H & BLOCK WAY  ...  64105.0       NaN  NaN      U
# 110496    NaN   RAYTOWN RD & I 435 HWY  ...      NaN       NaN  NaN      U
#
#        Invl_No  Involvement Race Sex  \
# 0            1          ARR    B   M
# 1            1          SUS    B   F
# 2            1          VIC    B   M
# 3            1          VIC    W   M
# 4            1          VIC    U   U
# ...        ...          ...  ...  ..
# 110492       1          VIC    U   U
# 110493       1          SUS    B   M
# 110494       1          SUS    U   U
# 110495       1          SUS    U   U
# 110496       1          VIC    U   M
#
#                                                Location 1 Firearm Used Flag
# 0                E 39 ST/GARFIELD AV\nKANSAS CITY 64109\n                 N
# 1                      7100 NW 86 TE\nKANSAS CITY 64153\n                 N
# 2                  E 39 ST/TROOST AV\nKANSAS CITY 64110\n                 N
# 3                         00 W 10 ST\nKANSAS CITY 64105\n                 N
# 4                   E 63 ST/SWOPE PK\nKANSAS CITY 64120\n                 N
# ...                                                   ...               ...
# 110492  EAST 63 TRFY &amp; LEWIS RD\nKANSAS CITY 64110...                 N
# 110493  41ST &amp; GILLHAM\nKANSAS CITY\n(39.052774, -...                 Y
# 110494              40 &amp; 435 HWY\nKANSAS CITY 64132\n                 N
# 110495  1 H &amp; BLOCK WAY\nKANSAS CITY 64105\n(39.09...                 N
# 110496  RAYTOWN RD &amp; I 435 HWY\nKANSAS CITY\n(38.9...                 N
#
# [110497 rows x 21 columns]

# %%
#Chuyển đổi cột 'Reported_Date' thành định dạng datetime
df['Reported_Date'] = pd.to_datetime(df['Reported_Date'])

# Lấy dataframe có City là Kansas City
kansas_city_df = df[df['City'] == 'KANSAS CITY']

# Nhóm dữ liệu theo ngày và thành phố, sau đó tính tổng số vụ phạm tội hàng ngày
daily_crime_counts = kansas_city_df.groupby(['Reported_Date', 'City']).size().reset_index(name='Total_Crimes')

df = daily_crime_counts.copy().drop(columns=['City'])

df.set_index('Reported_Date', inplace=True)

plt.figure(figsize=(10, 6))
plt.plot(df, color='lightpink')
plt.title('Daily Crime Counts in Kansas City')
plt.xlabel('Date')
plt.ylabel('Total Crimes')
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_20536\1901324064.py:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %% [markdown]
# # Mô hình SARIMA

# %%
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# ## Lựa chọn tham số ARIMA (p, d, q) và Yếu tố thời vụ

# %% [markdown]
# - Trong mô hình SARIMA (Seasonal Autoregressive Integrated Moving Average), có một số tham số quan trọng cần được xác định để xây dựng và ước lượng mô hình. Dưới đây là các tham số cơ bản và giải thích của chúng:
#     + p (AR order): Đây là số lượng các lag trong phần tự hồi quy tự động (AR). Tham số này xác định số lượng giá trị quan sát trong quá khứ được sử dụng để dự báo giá trị hiện tại. Ví dụ, nếu p = 2, mô hình sẽ sử dụng hai giá trị quan sát gần nhất để dự báo giá trị hiện tại.
#
#     + d (Integration order): Đây là mức độ sai phân tích hợp cần thực hiện trên chuỗi thời gian để làm cho nó ổn định và loại bỏ xu hướng. Tham số này đại diện cho số lần sai phân cần thực hiện trên chuỗi thời gian. Ví dụ, nếu d = 1, mô hình sẽ thực hiện một lần sai phân để loại bỏ xu hướng tuyến tính.
#
#     + q (MA order): Đây là số lượng các lag trong phần trung bình trượt di động (MA). Tham số này xác định số lượng giá trị phần tử ngẫu nhiên trong quá khứ được sử dụng để dự báo giá trị hiện tại. Ví dụ, nếu q = 2, mô hình sẽ sử dụng hai giá trị phần tử ngẫu nhiên gần nhất để dự báo giá trị hiện tại.
#
#     + P (Seasonal AR order): Đây là số lượng các lag trong phần tự hồi quy tự động mùa vụ. Tham số này tương tự như tham số p nhưng áp dụng cho yếu tố mùa vụ.
#
#     + D (Seasonal integration order): Tương tự như tham số d, tham số D xác định mức độ sai phân tích hợp mùa vụ cần thực hiện.
#
#     + Q (Seasonal MA order): Tương tự như tham số q, tham số Q xác định số lượng các lag trong phần trung bình trượt di động mùa vụ.
#
#     + s (Seasonal period): Đây là chu kỳ của yếu tố mùa vụ, tức là số lượng quan sát trong một chu kỳ mùa vụ. Ví dụ, nếu dữ liệu được thu thập hàng tháng và có yếu tố mùa vụ hàng năm, thì chu kỳ mùa vụ sẽ là 12.

# %% [markdown]
# ### Phân tích hàm tự tương quan (ACF)

# %%
# Phân tích hàm tự tương quan
plot_acf(df, lags=30)
plt.show()

# %% [markdown]
# ### Phân tích hàm tự tương quan riêng phần (PACF)

# %%
# Phân tích hàm tự tương quan riêng phần
plot_pacf(df, lags=30)
plt.show()

# %% [markdown]
# ### Phân chia tập train/test

# %%
# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
train_data = df.iloc[:len(df)-12]
test_data = df.iloc[len(df)-12:]
print('Train shape: ', train_data.shape)
print('Test shape: ', test_data.shape)
# Out:
# Train shape:  (299, 1)
# Test shape:  (12, 1)

# %% [markdown]
# ### Stepwise để tìm ra mô hình SARIMA tốt nhất

# %%
model_sarima = auto_arima(df, start_p=0, start_q=0,
                           max_p=5, max_q=5, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(model_sarima.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=inf, Time=0.69 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=3558.100, Time=0.22 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=3407.401, Time=0.52 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=2.00 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=3499.958, Time=0.33 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=3358.076, Time=1.32 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=9.45 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=2.40 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=3435.408, Time=1.22 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=3326.194, Time=1.86 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=3377.598, Time=0.80 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=6.30 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=2.37 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=3323.203, Time=2.31 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=3375.967, Time=0.91 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=inf, Time=7.02 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=2.44 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=3307.204, Time=3.30 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=3356.781, Time=1.42 sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=inf, Time=12.65 sec
#  ARIMA(4,1,0)(1,1,1)[12]             : AIC=inf, Time=4.65 sec
#  ARIMA(5,1,0)(2,1,0)[12]             : AIC=3295.402, Time=3.76 sec
#  ARIMA(5,1,0)(1,1,0)[12]             : AIC=3335.537, Time=1.70 sec
#  ARIMA(5,1,0)(2,1,1)[12]             : AIC=inf, Time=12.19 sec
#  ARIMA(5,1,0)(1,1,1)[12]             : AIC=inf, Time=2.96 sec
#  ARIMA(5,1,1)(2,1,0)[12]             : AIC=inf, Time=10.45 sec
#  ARIMA(4,1,1)(2,1,0)[12]             : AIC=inf, Time=9.55 sec
#  ARIMA(5,1,0)(2,1,0)[12] intercept   : AIC=3297.399, Time=10.04 sec
#
# Best model:  ARIMA(5,1,0)(2,1,0)[12]
# Total fit time: 114.891 seconds
# 3295.401886203143

# %% [markdown]
# - Từ kết quả ta có mô hình SARIMA(p=5, d=1, q=0)(p=2, D=1, q=0, m=12)

# %%
# Xác định các tham số cho mô hình SARIMA
order = (5, 1, 0)  # Tham số ARIMA (p, d, q)
seasonal_order = (2, 1, 0, 12)  # Tham số mùa vụ (P, D, Q, S)

# Xây dựng mô hình SARIMA
model = SARIMAX(df, order=order, seasonal_order=seasonal_order)
# Out:
# D:\Apps\Conda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# D:\Apps\Conda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.

# %%
# Khớp mô hình
result = model.fit()

# Đánh giá mô hình trên tập kiểm tra
predictions = result.predict(start=len(train_data), end=len(train_data)+len(test_data)-1, dynamic=False, typ='levels')

# %%
# Trực quan hóa kết quả
plt.figure(figsize=(10, 6))
plt.plot(train_data, label='Dữ liệu huấn luyện', color='lightpink')
plt.plot(test_data, label='Dữ liệu thử nghiệm', color='lightblue')
plt.plot(predictions, label='Dự đoán', color='green')
plt.title('SARIMA Model')
plt.xlabel('Date')
plt.ylabel('Total Crimes')
plt.legend()
plt.show()
